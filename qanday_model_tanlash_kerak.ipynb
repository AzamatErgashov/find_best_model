# %%
from IPython.display import Image

# %%
Image('modellar.jpg',width=600)

# %% [markdown]
# # bu modellarni qulaylik va kamchiliklari har kuni yangi modellar ishlab chqilyapti ularni korib ishlatib turish kerak
